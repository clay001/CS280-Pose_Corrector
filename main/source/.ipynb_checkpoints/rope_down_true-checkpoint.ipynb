# %%
import sys
import cv2
import os
from sys import platform
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
dir_path = '/root/final/main'
sys.path.append('/root/final/main')
sys.path.append('/usr/local/python/openpose')
from openpose import *

# %%
params = dict()
params["logging_level"] = 3
params["output_resolution"] = "-1x-1"
params["net_resolution"] = "-1x368"
params["model_pose"] = "BODY_25"
params["alpha_pose"] = 0.6
params["scale_gap"] = 0.25
params["scale_number"] = 1
params["render_threshold"] = 0.05
# If GPU version is built, and multiple GPUs are available, set the ID here
params["num_gpu"] = 1
params["num_gpu_start"] = 1
params["disable_blending"] = False
# Ensure you point to the correct path where models are located
params["default_model_folder"] = "/root/final/openpose/models/"
# Construct OpenPose object allocates GPU memory
openpose = OpenPose(params)

# %%
def get_md(point1 , point2):
    # return Manhattan Distance of point1 and point2
    # point1 and point2 are list
    test1 = np.array(point1)
    test2 = np.array(point2)
    return np.sqrt(np.sum(np.square(test1-test2)))


def get_angle(vec1,vec2):
    # return the angle of vector one to vector two 
    # negative if the vector 2 is in the clockwise of vector 1
    #vec1 and vec2 are list
    x = np.array(vec1)
    y = np.array(vec2)
    #lenth
    Lx = np.sqrt(x.dot(x))
    Ly = np.sqrt(y.dot(y))
    cos_angle = x.dot(y)/(Lx*Ly)
    angle = np.arccos(cos_angle)
    angle2 = angle*360/2/np.pi
    crossdd = np.cross(x,y)
    if (crossdd <= 0):
        return angle2
    else:
        return -angle2

# %%
test1 = "barbell_curls_true"
test2 = "barbell_curls_wrong"
test3 = "dumbbell_lateral_raise_true"
test4 = "dumbbell_lateral_raise_wrong"
test5 = "dumbbell_lateral_raise_whole_true"
test6 = "dumbbell_lateral_raise_whole_wrong1"
test7 = "dumbbell_lateral_raise_whole_wrong2"
test8 = "dumbbell_rowing_true"
test9 = "dumbbell_rowing_wrong"
test10 = "rope_down_true"
test11 = "rope_down_wrong"
test12 = "squat_true"
test13 = "squat_wrong"
# the path of the video
input_path = "/root/final/main/test_video/test_video1/"
input_video = test10
input_type = ".mp4"
cap = cv2.VideoCapture(input_path+input_video+input_type)
# create the output folder
folder = os.path.exists("output_video/"+ input_video) 
if not folder:                  
    os.makedirs("output_video/"+ input_video) 

count = 0
num_count = 0
theta1_list = [] 
theta2_list = []
theta3_list = []
feedback = []     
index_count = [] 
while(cap.isOpened()):
    ret, frame = cap.read()
    if frame is None:
        break;
    if count% 3==0 :
        num_count +=1
        if num_count == 65:
            continue
        # following 2 lines are used for test
        frame=cv2.transpose(frame)
        frame=cv2.flip(frame,1)
        #print(frame.shape)
        #plt.imshow(frame)
        #plt.show() 
        #break
        #return the keypoints and rendered output images
        keypoints, output_image = openpose.forward(frame, True)
        # Print the human pose keypoints, i.e., a [#people x #keypoints x 3]-dimensional numpy object with the keypoints of all the people on that image
        #print(keypoints)
        #print(output_image.shape)
        #plt.imshow(output_image)
        #plt.show()
        # store the image
        temp_name = str(count)
        while(len(temp_name)!=4):
            temp_name = "0"+temp_name
        store_name = "output_video/"+ input_video + "/" + temp_name+".jpg"
        index_count.append(store_name)
        print(store_name)
        cv2.imwrite(store_name, output_image);
        # deal with the keypoints
        [people_num , point_num, channel] = keypoints.shape
        # to choose the domaint skleton
        #print(people_num)
        if (people_num != 1):
            best_index = 0
            best_dist = 0 
            for index in range(people_num):
                point1 = [keypoints[index,1,0] , keypoints[index,1,1]  ]
                point8 = [keypoints[index,8,0] , keypoints[index,8,1]  ]
                dist = get_md(point1,point8)
                if (dist > best_dist):
                    best_index = index
                    best_dist = dist
            keypoint = keypoints[best_index,:,:]
        else:
            keypoint = keypoints
        keypoint = np.squeeze(keypoint)
                # here determine whether is right or left hand
        #print(keypoint)
        right_hand = np.array([ math.ceil(keypoint[2,2]) ,math.ceil(keypoint[3,2]) ,math.ceil(keypoint[4,2]) ])
        left_hand = np.array([ math.ceil(keypoint[5,2]) ,math.ceil(keypoint[6,2]) ,math.ceil(keypoint[7,2]) ])
        right_confidence  = keypoint[2,2] + keypoint[3,2] + keypoint[4,2]
        left_confidence = keypoint[5,2] + keypoint[6,2] + keypoint[7,2]
        #print(right_confidence , left_confidence)
        #print(right_hand,' right hand')
        #print(left_hand,' left hand')
        #print( keypoint[0,2,2] , keypoint[0,3,2] ,keypoint[0,4,2] , ' right confidence')
        #print( keypoint[0,5,2] , keypoint[0,6,2] ,keypoint[0,7,2] , ' left confidence')
        output_flag = 0 
        if ((np.sum(right_hand) == 3) & (right_confidence >= left_confidence) ):
            side = 'right'
            output_flag = 1
            shoulder_point =  [keypoint[2,0] , keypoint[2,1] ] 
            elbow_point =  [keypoint[3,0] , keypoint[3,1]  ] 
            wrist_point =  [keypoint[4,0] , keypoint[4,1]  ]  
        elif ((np.sum(left_hand) == 3) & (right_confidence < left_confidence) ):
            side = 'left'
            output_flag = 1
            shoulder_point =  [keypoint[5,0] , keypoint[5,1] ] 
            elbow_point =   [keypoint[6,0] , keypoint[6,1]  ] 
            wrist_point =  [keypoint[7,0] , keypoint[7,1]  ]
        neck_point = [keypoint[1,0] , keypoint[1,1] ]
        midhip_point = [keypoint[8,0] , keypoint[8,1] ]
        #print(side)
        # first calculate the angle between the line(neck,midhip) with vertical
        vec1 = np.array(midhip_point) - np.array(neck_point)
        vec2 = np.array([neck_point[0],neck_point[1]+2]) -np.array(neck_point)
        theta1= get_angle( vec1 ,vec2 )
        if side == 'right':
            theta1_list.append(theta1)
        else:
            theta1_list.append(-theta1)
        #print(theta1)
        # then calculate the angle between the line(elbow,wrist) with vertical
        vec1 = np.array(wrist_point) - np.array(elbow_point)
        vec2 = np.array([elbow_point[0],elbow_point[1]+2]) -np.array(elbow_point)
        theta2= get_angle( vec1 ,vec2 )
        if side == 'right':
            theta2_list.append(-theta2)
        else:
            print(store_name)
            theta2_list.append(theta2)
        #print(theta2) 
        # next calculate the angle between the line(shoulder , elbow) with line(neck , midhip)
        vec1 = np.array(midhip_point) - np.array(neck_point) 
        vec2 = np.array(elbow_point) - np.array(shoulder_point)
        theta3= get_angle( vec1 ,vec2 )
        if side == 'right':
            theta3_list.append(theta3)
        else:
            theta3_list.append(-theta3)
        #print(theta3) 
    count+=1
    
#####################################################
### special case  here ,ow, omit this.NO.192 is mismatching
#####################################################
num_count -=1
#####################################################
print(count)
# Out:
# output_video/rope_down_true/0000.jpg
# output_video/rope_down_true/0003.jpg
# output_video/rope_down_true/0006.jpg
# output_video/rope_down_true/0009.jpg
# output_video/rope_down_true/0012.jpg
# output_video/rope_down_true/0015.jpg
# output_video/rope_down_true/0018.jpg
# output_video/rope_down_true/0021.jpg
# output_video/rope_down_true/0024.jpg
# output_video/rope_down_true/0027.jpg
# output_video/rope_down_true/0030.jpg
# output_video/rope_down_true/0033.jpg
# output_video/rope_down_true/0036.jpg
# output_video/rope_down_true/0039.jpg
# output_video/rope_down_true/0042.jpg
# output_video/rope_down_true/0045.jpg
# output_video/rope_down_true/0048.jpg
# output_video/rope_down_true/0051.jpg
# output_video/rope_down_true/0054.jpg
# output_video/rope_down_true/0057.jpg
# output_video/rope_down_true/0060.jpg
# output_video/rope_down_true/0063.jpg
# output_video/rope_down_true/0066.jpg
# output_video/rope_down_true/0069.jpg
# output_video/rope_down_true/0072.jpg
# output_video/rope_down_true/0075.jpg
# output_video/rope_down_true/0078.jpg
# output_video/rope_down_true/0081.jpg
# output_video/rope_down_true/0084.jpg
# output_video/rope_down_true/0087.jpg
# output_video/rope_down_true/0090.jpg
# output_video/rope_down_true/0093.jpg
# output_video/rope_down_true/0096.jpg
# output_video/rope_down_true/0099.jpg
# output_video/rope_down_true/0102.jpg
# output_video/rope_down_true/0105.jpg
# output_video/rope_down_true/0108.jpg
# output_video/rope_down_true/0111.jpg
# output_video/rope_down_true/0114.jpg
# output_video/rope_down_true/0117.jpg
# output_video/rope_down_true/0120.jpg
# output_video/rope_down_true/0123.jpg
# output_video/rope_down_true/0126.jpg
# output_video/rope_down_true/0129.jpg
# output_video/rope_down_true/0132.jpg
# output_video/rope_down_true/0135.jpg
# output_video/rope_down_true/0138.jpg
# output_video/rope_down_true/0141.jpg
# output_video/rope_down_true/0144.jpg
# output_video/rope_down_true/0147.jpg
# output_video/rope_down_true/0150.jpg
# output_video/rope_down_true/0153.jpg
# output_video/rope_down_true/0156.jpg
# output_video/rope_down_true/0159.jpg
# output_video/rope_down_true/0162.jpg
# output_video/rope_down_true/0165.jpg
# output_video/rope_down_true/0168.jpg
# output_video/rope_down_true/0171.jpg
# output_video/rope_down_true/0174.jpg
# output_video/rope_down_true/0177.jpg
# output_video/rope_down_true/0180.jpg
# output_video/rope_down_true/0183.jpg
# output_video/rope_down_true/0186.jpg
# output_video/rope_down_true/0189.jpg
# output_video/rope_down_true/0192.jpg
# output_video/rope_down_true/0195.jpg
# output_video/rope_down_true/0198.jpg
# output_video/rope_down_true/0201.jpg
# output_video/rope_down_true/0204.jpg
# output_video/rope_down_true/0207.jpg
# output_video/rope_down_true/0210.jpg
# output_video/rope_down_true/0213.jpg
# output_video/rope_down_true/0216.jpg
# output_video/rope_down_true/0219.jpg
# output_video/rope_down_true/0222.jpg
# output_video/rope_down_true/0225.jpg
# output_video/rope_down_true/0228.jpg
# output_video/rope_down_true/0231.jpg
# output_video/rope_down_true/0234.jpg
# output_video/rope_down_true/0237.jpg
# output_video/rope_down_true/0240.jpg
# output_video/rope_down_true/0243.jpg
# output_video/rope_down_true/0246.jpg
# output_video/rope_down_true/0249.jpg
# output_video/rope_down_true/0252.jpg
# output_video/rope_down_true/0255.jpg
# output_video/rope_down_true/0258.jpg
# output_video/rope_down_true/0261.jpg
# output_video/rope_down_true/0264.jpg
# output_video/rope_down_true/0267.jpg
# output_video/rope_down_true/0270.jpg
# output_video/rope_down_true/0273.jpg
# output_video/rope_down_true/0276.jpg
# output_video/rope_down_true/0279.jpg
# output_video/rope_down_true/0282.jpg
# output_video/rope_down_true/0285.jpg
# output_video/rope_down_true/0288.jpg
# output_video/rope_down_true/0291.jpg
# output_video/rope_down_true/0294.jpg
# output_video/rope_down_true/0297.jpg
# output_video/rope_down_true/0300.jpg
# output_video/rope_down_true/0303.jpg
# output_video/rope_down_true/0306.jpg
# output_video/rope_down_true/0309.jpg
# output_video/rope_down_true/0312.jpg
# output_video/rope_down_true/0315.jpg
# output_video/rope_down_true/0318.jpg
# output_video/rope_down_true/0321.jpg
# output_video/rope_down_true/0324.jpg
# output_video/rope_down_true/0327.jpg
# output_video/rope_down_true/0330.jpg
# output_video/rope_down_true/0333.jpg
# output_video/rope_down_true/0336.jpg
# output_video/rope_down_true/0339.jpg
# output_video/rope_down_true/0342.jpg
# output_video/rope_down_true/0345.jpg
# output_video/rope_down_true/0348.jpg
# output_video/rope_down_true/0351.jpg
# output_video/rope_down_true/0354.jpg
# output_video/rope_down_true/0357.jpg
# output_video/rope_down_true/0360.jpg
# output_video/rope_down_true/0363.jpg
# output_video/rope_down_true/0366.jpg
# output_video/rope_down_true/0369.jpg
# output_video/rope_down_true/0372.jpg
# output_video/rope_down_true/0375.jpg
# output_video/rope_down_true/0378.jpg
# output_video/rope_down_true/0381.jpg
# output_video/rope_down_true/0384.jpg
# output_video/rope_down_true/0387.jpg
# output_video/rope_down_true/0390.jpg
# output_video/rope_down_true/0393.jpg
# output_video/rope_down_true/0396.jpg
# output_video/rope_down_true/0399.jpg
# output_video/rope_down_true/0402.jpg
# output_video/rope_down_true/0405.jpg
# output_video/rope_down_true/0408.jpg
# output_video/rope_down_true/0411.jpg
# output_video/rope_down_true/0414.jpg
# output_video/rope_down_true/0417.jpg
# output_video/rope_down_true/0420.jpg
# output_video/rope_down_true/0423.jpg
# output_video/rope_down_true/0426.jpg
# output_video/rope_down_true/0429.jpg
# output_video/rope_down_true/0432.jpg
# output_video/rope_down_true/0435.jpg
# output_video/rope_down_true/0438.jpg
# output_video/rope_down_true/0441.jpg
# output_video/rope_down_true/0444.jpg
# output_video/rope_down_true/0447.jpg
# output_video/rope_down_true/0450.jpg
# output_video/rope_down_true/0453.jpg
# output_video/rope_down_true/0456.jpg
# output_video/rope_down_true/0459.jpg
# output_video/rope_down_true/0462.jpg
# output_video/rope_down_true/0465.jpg
# output_video/rope_down_true/0468.jpg
# output_video/rope_down_true/0471.jpg
# output_video/rope_down_true/0474.jpg
# output_video/rope_down_true/0477.jpg
# output_video/rope_down_true/0480.jpg
# output_video/rope_down_true/0483.jpg
# output_video/rope_down_true/0486.jpg
# output_video/rope_down_true/0489.jpg
# output_video/rope_down_true/0492.jpg
# output_video/rope_down_true/0495.jpg
# output_video/rope_down_true/0498.jpg
# output_video/rope_down_true/0501.jpg
# output_video/rope_down_true/0504.jpg
# output_video/rope_down_true/0507.jpg
# output_video/rope_down_true/0510.jpg
# output_video/rope_down_true/0513.jpg
# output_video/rope_down_true/0516.jpg
# output_video/rope_down_true/0519.jpg
# output_video/rope_down_true/0522.jpg
# output_video/rope_down_true/0525.jpg
# output_video/rope_down_true/0528.jpg
# output_video/rope_down_true/0531.jpg
# output_video/rope_down_true/0534.jpg
# output_video/rope_down_true/0537.jpg
# output_video/rope_down_true/0540.jpg
# output_video/rope_down_true/0543.jpg
# output_video/rope_down_true/0546.jpg
# output_video/rope_down_true/0549.jpg
# output_video/rope_down_true/0552.jpg
# output_video/rope_down_true/0555.jpg
# output_video/rope_down_true/0558.jpg
# output_video/rope_down_true/0561.jpg
# output_video/rope_down_true/0564.jpg
# output_video/rope_down_true/0567.jpg
# output_video/rope_down_true/0570.jpg
# output_video/rope_down_true/0573.jpg
# output_video/rope_down_true/0576.jpg
# output_video/rope_down_true/0579.jpg
# output_video/rope_down_true/0582.jpg
# output_video/rope_down_true/0585.jpg
# output_video/rope_down_true/0588.jpg
# output_video/rope_down_true/0591.jpg
# output_video/rope_down_true/0594.jpg
# output_video/rope_down_true/0597.jpg
# output_video/rope_down_true/0600.jpg
# output_video/rope_down_true/0603.jpg
# output_video/rope_down_true/0606.jpg
# output_video/rope_down_true/0609.jpg
# output_video/rope_down_true/0612.jpg
# output_video/rope_down_true/0615.jpg
# 617

# %%
x1 = range(0, len(theta2_list))
y1 = theta2_list
plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('line(elbow,wrist) with vertical')
plt.ylabel('degree')

plt.show()

# %%
x1 = range(0, len(theta1_list))
y1 = theta1_list
plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('line(neck,midhip) with vertical')
plt.ylabel('degree')

plt.show()

# %%
x1 = range(0, len(theta3_list))
y1 = theta3_list
plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'o-')
plt.title('line(shoulder , elbow) with line(neck , midhip)')
plt.ylabel('degree')

plt.show()

# %%
# try to deal with each action seperately
feedbacks = []
seperate_point = []

####
# to store the frame of wrong action
feedbacks_image = []
####

# to store the whole 


import peakutils
theta2_list_temp = np.array(theta2_list)
seperate_points = peakutils.indexes(theta2_list_temp, thres=0.03/max(theta2_list_temp), min_dist=40)
print(seperate_points)
for index_x in range(0,len(seperate_points)-1):
    print(index_x)
    feedback_temp = ['None','None','None','None','None']
    feedback_image_temp = ['None','None','None','None','None']
    test_theta1_list =  theta1_list[ seperate_points[index_x] :  seperate_points[index_x+1] ]
    test_theta2_list =  theta2_list[ seperate_points[index_x] :  seperate_points[index_x+1] ]
    test_theta3_list =  theta3_list[ seperate_points[index_x] :  seperate_points[index_x+1] ]
    
    # theta1_list  part1
    max_theta1 = max(test_theta1_list)
    min_theta1 = min(test_theta1_list)
    #print(max_theta1,min_theta1)
    if (max_theta1 - min_theta1 > 12):
        feedback_temp[0]=('Keep your body fixed! Do not shake!')
    else:
    # theta1_list  part2
        max_theta1 = max(test_theta1_list,key = abs)
        min_theta1 = min(test_theta1_list,key = abs)
        if (max_theta1 > 20):
            max_index = theta1_list.index(max_theta1)
            feedback_image_temp[1]= index_count[max_index]
            feedback_temp[1]=('Leaning too much! Straight a little!')
        if (min_theta1 < 5):
            min_index = theta1_list.index(min_theta1)
            feedback_image_temp[2]= index_count[min_index]
            feedback_temp[2]=('Leaning your back a little!')    
    
    # theta2_list
    max_theta2 = max(test_theta2_list)
    min_theta2 = min(test_theta2_list)
    #print( max_theta2, min_theta2 )
    if (max_theta2 >= 140):
        max_index = theta2_list.index(max_theta2)
        feedback_image_temp[3]= index_count[max_index]        
        feedback_temp[3]=( 'Go up too much!, it is better to lower '+str(round(max_theta2 -130))+' degrees!' )   
    
    # theta3_list
    max_theta3 = max(test_theta3_list, key = abs)
    #print(max_theta3,min_theta3)
    if ( max_theta3 > 10) :
        max_index = theta3_list.index(max_theta3)
        feedback_image_temp[4]= index_count[max_index] 
        feedback_temp[4]=('Keep your hands close to your body!')
    feedbacks.append(feedback_temp)
    feedbacks_image.append(feedback_image_temp)
# Out:
# [  2  47 104 154 204]
# 0
# 1
# 2
# 3

# %%
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 6.0)
for each_x in range(len(seperate_points)-1):
    print("In the "+ str(each_x+1) +" turn, you have several problems:")
    feedback = feedbacks[each_x]
    image_part = feedbacks_image[each_x]
    if feedback == ['None','None','None','None','None']:
        print('Good Jobs!!!!!')
    else:
        for each_y in range(len(feedback)):
            if feedback[each_y] != 'None':
                
                if image_part[each_y] != 'None':
                    print('\033[1;35m',feedback[each_y])
                    #print(image_part[each_y])
                    
                    img = cv2.imread(image_part[each_y]);
                    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                    plt.imshow(img)
                    plt.show()
                else:
                    print(feedback[each_y])

    print('~~~~~~~~~~~~~~~~~~~~~~')
# Out:
# In the 1 turn, you have several problems:
#  Keep your hands close to your body!
# ~~~~~~~~~~~~~~~~~~~~~~
# In the 2 turn, you have several problems:
#  Keep your hands close to your body!
# ~~~~~~~~~~~~~~~~~~~~~~
# In the 3 turn, you have several problems:
#  Keep your hands close to your body!
# ~~~~~~~~~~~~~~~~~~~~~~
# In the 4 turn, you have several problems:
#  Keep your hands close to your body!
# ~~~~~~~~~~~~~~~~~~~~~~
